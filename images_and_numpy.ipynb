# %% [markdown]
# <a href="https://colab.research.google.com/github/hamednasr/coputer-vision/blob/main/images_and_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open('/content/drive/MyDrive/Colab Notebooks/Open CV jose portilla course/child.jpg')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=311x162 at 0x7FD5150D3210>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic_arr)

# %%
img = plt.imread('/content/drive/MyDrive/Colab Notebooks/Open CV jose portilla course/child.jpg')

# %%
plt.imshow(img);

# %%
img.shape
# Out:
# (162, 311, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#red channel
pic_red = pic_arr[:,:,0]
plt.imshow(pic_red,cmap='gray')

# %%
#green channel
pic_green = pic_arr[:,:,1]
plt.imshow(pic_green,cmap='gray')

# %%
#blue channel
pic_blue = pic_arr[:,:,1]
plt.imshow(pic_blue,cmap='gray')

# %%
#RED image

# %%
pic_arr[:,:,1]=0
pic_arr[:,:,2]=0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a8b4519fbb72> in <module>()
# ----> 1 pic_arr[:,:,1]=0
#       2 pic_arr[:,:,2]=0
#
# ValueError: assignment destination is read-only

# %%
pic_arr[:,:,1] = 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-539b60a27e51> in <module>()
# ----> 1 pic_arr[:,:,1] = 0
#
# ValueError: assignment destination is read-only

# %%
pic_arr.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
pic_arr.setflags(write=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-13f698653ee0> in <module>()
# ----> 1 pic_arr.setflags(write=1)
#
# ValueError: cannot set WRITEABLE flag to True of this array
